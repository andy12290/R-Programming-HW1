# %%
data(cars)
data = cars

# %%
head(data)
# Out:
#   speed dist
# 1 4      2
# 2 4     10
# 3 7      4
# 4 7     22
# 5 8     16
# 6 9     10

# %%
dim(data)
# Out:
# [1] 50  2

# %%
plot(data$speed,data$dist)
# Out:
# plot without title

# %%
lm(data$dist~data$speed)
# Out:
# Call:
# lm(formula = data$dist ~ data$speed)
#
# Coefficients:
# (Intercept)   data$speed
#     -17.579        3.932

# %%
summary(data)
# Out:
#      speed           dist
#  Min.   : 4.0   Min.   :  2.00
#  1st Qu.:12.0   1st Qu.: 26.00
#  Median :15.0   Median : 36.00
#  Mean   :15.4   Mean   : 42.98
#  3rd Qu.:19.0   3rd Qu.: 56.00
#  Max.   :25.0   Max.   :120.00

# %%
lm(formula = data$dist~data$speed )
# Out:
# Call:
# lm(formula = data$dist ~ data$speed)
#
# Coefficients:
# (Intercept)   data$speed
#     -17.579        3.932

# %%
summary(lm(data$dist~data$speed))
# Out:
# Call:
# lm(formula = data$dist ~ data$speed)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -29.069  -9.525  -2.272   9.215  43.201
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -17.5791     6.7584  -2.601   0.0123 *
# data$speed    3.9324     0.4155   9.464 1.49e-12 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 15.38 on 48 degrees of freedom
# Multiple R-squared:  0.6511,	Adjusted R-squared:  0.6438
# F-statistic: 89.57 on 1 and 48 DF,  p-value: 1.49e-12

# %%
plot(lm(data$dist~data$speed))
# Out:
# Plot with title “”
# Plot with title “”
# Plot with title “”
# Plot with title “”

# %%
hist(resid(lm(data$dist~data$speed)))
# Out:
# Plot with title “Histogram of resid(lm(data$dist ~ data$speed))”

# %%
lm_without_49 = lm(data$dist[49]~data$speed[49])

# %%
resid(lm_without_49)
# Out:
# 1
# 0

# %%
data <- read.csv('MLR_houseprices.csv')
head(data)
# Out:
#   Price Size.SqFt Age.years Num.Rooms
# 1 119.0 2069      40         6
# 2 124.8 1600      30         8
# 3 159.0 2100      27         7
# 4 183.9 2752      35        10
# 5 200.0 2300      18         8
# 6 211.2 2525      17         8

# %%
mlr = lm(data$Price~data$Size.SqFt+data$Age.years+data$Num.Rooms)
mlr
# Out:
# Call:
# lm(formula = data$Price ~ data$Size.SqFt + data$Age.years + data$Num.Rooms)
#
# Coefficients:
#    (Intercept)  data$Size.SqFt  data$Age.years  data$Num.Rooms
#       85.82614         0.06897        -1.67483        -3.43180

# %%
summary(mlr)
# Out:
# Call:
# lm(formula = data$Price ~ data$Size.SqFt + data$Age.years + data$Num.Rooms)
#
# Residuals:
#       1       2       3       4       5       6       7       8       9
# -21.942   6.321  -2.421   1.205  13.144   7.151  13.246  -4.854 -11.849
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)    85.82614   38.37988   2.236   0.0756 .
# data$Size.SqFt  0.06897    0.01582   4.359   0.0073 **
# data$Age.years -1.67483    0.55651  -3.009   0.0298 *
# data$Num.Rooms -3.43180    5.06198  -0.678   0.5279
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 14.78 on 5 degrees of freedom
# Multiple R-squared:  0.9255,	Adjusted R-squared:  0.8809
# F-statistic: 20.72 on 3 and 5 DF,  p-value: 0.002999

# %%
mlr = lm(data$Price~data$Size.SqFt+data$Age.years)
summary(mlr)
# Out:
# Call:
# lm(formula = data$Price ~ data$Size.SqFt + data$Age.years)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -18.9200  -7.0052   0.0534  11.7004  15.6465
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)    71.083941  30.167689   2.356 0.056570 .
# data$Size.SqFt  0.060772   0.009733   6.244 0.000782 ***
# data$Age.years -1.472511   0.448085  -3.286 0.016692 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 14.1 on 6 degrees of freedom
# Multiple R-squared:  0.9187,	Adjusted R-squared:  0.8916
# F-statistic:  33.9 on 2 and 6 DF,  p-value: 0.0005374

# %%
hist(resid(mlr))
# Out:
# Plot with title “Histogram of resid(mlr)”

# %%
shapiro.test(resid(mlr))
# Out:
# 	Shapiro-Wilk normality test
#
# data:  resid(mlr)
# W = 0.94127, p-value = 0.5954

# %%
data = read.csv('MLR_starbucks.csv')
head(data)
# Out:
#   Prepaid.Card Age Day.Month Cups.Day Income AverageReceiptTotal
# 1  20          25   4        2        10000  2.38
# 2  80          30  12        4        50000  4.80
# 3  60          27  10        3        20000  3.07
# 4  60          42   8        3        20000  2.96
# 5  75          29  11        2        35000  3.97
# 6 150          25  12        6        90000  7.59

# %%
mlr = lm(data$Prepaid.Card~data$Age+data$Day.Month+data$Cups.Day+data$Income+data$AverageReceiptTotal)
mlr
# Out:
# Call:
# lm(formula = data$Prepaid.Card ~ data$Age + data$Day.Month +
#     data$Cups.Day + data$Income + data$AverageReceiptTotal)
#
# Coefficients:
#              (Intercept)                  data$Age            data$Day.Month
#               -2.5752145                -0.0648296                 0.5827846
#            data$Cups.Day               data$Income  data$AverageReceiptTotal
#                3.0795119                 0.0005266                 8.5111486

# %%
summary(mlr)
# Out:
# Call:
# lm(formula = data$Prepaid.Card ~ data$Age + data$Day.Month +
#     data$Cups.Day + data$Income + data$AverageReceiptTotal)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -33.372  -8.720  -1.725  12.598  18.768
#
# Coefficients:
#                            Estimate Std. Error t value Pr(>|t|)
# (Intercept)              -2.5752145 16.9599775  -0.152  0.88091
# data$Age                 -0.0648296  0.3897402  -0.166  0.86965
# data$Day.Month            0.5827846  0.8433883   0.691  0.49792
# data$Cups.Day             3.0795119  4.5028876   0.684  0.50230
# data$Income               0.0005266  0.0002632   2.001  0.05989 .
# data$AverageReceiptTotal  8.5111486  2.8176097   3.021  0.00703 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 15.25 on 19 degrees of freedom
# Multiple R-squared:  0.8988,	Adjusted R-squared:  0.8721
# F-statistic: 33.74 on 5 and 19 DF,  p-value: 8.145e-09

# %%
mlr = lm(data$Prepaid.Card~data$Income+data$AverageReceiptTotal)
summary(mlr)
# Out:
# Call:
# lm(formula = data$Prepaid.Card ~ data$Income + data$AverageReceiptTotal)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -31.859 -11.111   0.109  11.580  18.603
#
# Coefficients:
#                           Estimate Std. Error t value Pr(>|t|)
# (Intercept)              5.4549390  5.8819150   0.927 0.363778
# data$Income              0.0005926  0.0002309   2.566 0.017608 *
# data$AverageReceiptTotal 9.6234586  2.3574110   4.082 0.000494 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 14.51 on 22 degrees of freedom
# Multiple R-squared:  0.8938,	Adjusted R-squared:  0.8842
# F-statistic: 92.59 on 2 and 22 DF,  p-value: 1.935e-11

# %%
data <- read.csv('LogisticReg_MortgageApproval.csv')
head(data)
# Out:
#   Approved Down.Payment Income.to.Loan Stable.Household
# 1 Approved 16.35        49.94          Stable
# 2 Approved 34.43        56.16          Stable
# 3 Approved 39.19        36.89          Stable
# 4 Approved 23.58        56.88          Not Stable
# 5 Denied   29.92        27.05          Stable
# 6 Approved 25.26        44.38          Not Stable

# %%
data <- within(data, data$Approved <- relevel(Approved, ref="Denied"))
logreg <- glm(data$Approved ~ data$Down.Payment+data$Income.to.Loan+data$Stable.Household, family = 'binomial', data = data)

# %%
summary(logreg)
# Out:
# Call:
# glm(formula = data$Approved ~ data$Down.Payment + data$Income.to.Loan +
#     data$Stable.Household, family = "binomial", data = data)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.0452  -0.5424   0.1580   0.4592   2.3462
#
# Coefficients:
#                             Estimate Std. Error z value Pr(>|z|)
# (Intercept)                 -9.30148    3.22897  -2.881  0.00397 **
# data$Down.Payment            0.13430    0.06470   2.076  0.03791 *
# data$Income.to.Loan          0.17464    0.06788   2.573  0.01009 *
# data$Stable.HouseholdStable  0.19401    1.17903   0.165  0.86930
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 41.054  on 29  degrees of freedom
# Residual deviance: 21.808  on 26  degrees of freedom
# AIC: 29.808
#
# Number of Fisher Scoring iterations: 5

# %%
logreg <- glm(data$Approved ~ data$Down.Payment+data$Income.to.Loan, family = 'binomial', data = data)
summary(logreg)
# Out:
# Call:
# glm(formula = data$Approved ~ data$Down.Payment + data$Income.to.Loan,
#     family = "binomial", data = data)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.0920  -0.5579   0.1630   0.4738   2.3374
#
# Coefficients:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)         -9.36709    3.19580  -2.931  0.00338 **
# data$Down.Payment    0.13490    0.06401   2.107  0.03508 *
# data$Income.to.Loan  0.17822    0.06463   2.758  0.00582 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 41.054  on 29  degrees of freedom
# Residual deviance: 21.835  on 27  degrees of freedom
# AIC: 27.835
#
# Number of Fisher Scoring iterations: 5

# %%
library(ROCR)
